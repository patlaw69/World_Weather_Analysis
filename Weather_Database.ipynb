# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=465044665732f2c02a9a3593d2b86a5b

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
                
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | raudeberg
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | maniitsoq
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | valdivia
# Processing Record 8 of Set 1 | harper
# Processing Record 9 of Set 1 | asau
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | mitsamiouli
# Processing Record 13 of Set 1 | quatre cocos
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | berlevag
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | hirara
# Processing Record 28 of Set 1 | rio grande
# Processing Record 29 of Set 1 | tukrah
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | derzhavinsk
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | sungaipenuh
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | honiara
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | bunia
# Processing Record 41 of Set 1 | winslow
# Processing Record 42 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 43 of Set 1 | hervey bay
# Processing Record 44 of Set 1 | kruisfontein
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | turbat
# Processing Record 48 of Set 1 | libreville
# Processing Record 49 of Set 1 | chinsali
# Processing Record 50 of Set 1 | lazaro cardenas
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | key largo
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | sinnamary
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | kalbay
# Processing Record 8 of Set 2 | margate
# Processing Record 9 of Set 2 | santa margherita ligure
# Processing Record 10 of Set 2 | urumqi
# Processing Record 11 of Set 2 | kochi
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | nizhniy mamon
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | mabai
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | kedrovyy
# Processing Record 20 of Set 2 | sidi ali
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | greytown
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | kibre mengist
# Processing Record 26 of Set 2 | totolapan
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | boende
# Processing Record 29 of Set 2 | farafangana
# Processing Record 30 of Set 2 | rocha
# Processing Record 31 of Set 2 | srednekolymsk
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | senador jose porfirio
# Processing Record 34 of Set 2 | grand gaube
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | nemuro
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | xining
# Processing Record 40 of Set 2 | dogondoutchi
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | bulgan
# Processing Record 47 of Set 2 | nuuk
# Processing Record 48 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 2 | yambio
# Processing Record 50 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | makakilo city
# Processing Record 2 of Set 3 | vilcun
# Processing Record 3 of Set 3 | cockburn town
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | maceio
# Processing Record 6 of Set 3 | gangavalli
# Processing Record 7 of Set 3 | taksimo
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | coolum beach
# Processing Record 10 of Set 3 | zhigalovo
# Processing Record 11 of Set 3 | batagay-alyta
# Processing Record 12 of Set 3 | port hedland
# Processing Record 13 of Set 3 | sheffield lake
# Processing Record 14 of Set 3 | atuona
# Processing Record 15 of Set 3 | vestmannaeyjar
# Processing Record 16 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 3 | saint-pierre
# Processing Record 18 of Set 3 | hofn
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | lavrentiya
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | tautira
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | nadym
# Processing Record 28 of Set 3 | solnechnyy
# Processing Record 29 of Set 3 | waipawa
# Processing Record 30 of Set 3 | khomeynishahr
# City not found. Skipping...
# Processing Record 31 of Set 3 | gari
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | tutoia
# Processing Record 36 of Set 3 | beloha
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | ust-nera
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | fort nelson
# Processing Record 41 of Set 3 | lensk
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 3 | cayenne
# Processing Record 45 of Set 3 | sturgis
# Processing Record 46 of Set 3 | minakuchi
# Processing Record 47 of Set 3 | yerbogachen
# Processing Record 48 of Set 3 | cape town
# Processing Record 49 of Set 3 | dinguiraye
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | shingu
# Processing Record 2 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 4 | zaliztsi
# Processing Record 4 of Set 4 | vila velha
# Processing Record 5 of Set 4 | shakiso
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | hohhot
# Processing Record 8 of Set 4 | danshui
# Processing Record 9 of Set 4 | half moon bay
# Processing Record 10 of Set 4 | erdenet
# Processing Record 11 of Set 4 | pitimbu
# Processing Record 12 of Set 4 | shimoda
# Processing Record 13 of Set 4 | uch
# Processing Record 14 of Set 4 | hailar
# Processing Record 15 of Set 4 | ondjiva
# Processing Record 16 of Set 4 | san jose
# Processing Record 17 of Set 4 | qurayyat
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | pasni
# Processing Record 20 of Set 4 | udachnyy
# Processing Record 21 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 4 | nicoya
# Processing Record 23 of Set 4 | taoudenni
# Processing Record 24 of Set 4 | champasak
# Processing Record 25 of Set 4 | diu
# Processing Record 26 of Set 4 | airai
# Processing Record 27 of Set 4 | pomichna
# Processing Record 28 of Set 4 | la fleche
# Processing Record 29 of Set 4 | okhotsk
# Processing Record 30 of Set 4 | mahebourg
# Processing Record 31 of Set 4 | yarim
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | goderich
# Processing Record 34 of Set 4 | lakes entrance
# Processing Record 35 of Set 4 | general pico
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | deputatskiy
# Processing Record 38 of Set 4 | kalemie
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | ostersund
# Processing Record 41 of Set 4 | qaanaaq
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | anadyr
# Processing Record 44 of Set 4 | beringovskiy
# Processing Record 45 of Set 4 | point pleasant
# Processing Record 46 of Set 4 | masyaf
# Processing Record 47 of Set 4 | tiarei
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | nichinan
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | kashary
# Processing Record 2 of Set 5 | ayagoz
# Processing Record 3 of Set 5 | riyadh
# Processing Record 4 of Set 5 | yumen
# Processing Record 5 of Set 5 | sioux lookout
# Processing Record 6 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 5 | acari
# Processing Record 8 of Set 5 | mongu
# Processing Record 9 of Set 5 | lake city
# Processing Record 10 of Set 5 | cap malheureux
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | canutama
# Processing Record 13 of Set 5 | xai-xai
# Processing Record 14 of Set 5 | imeni poliny osipenko
# Processing Record 15 of Set 5 | oranjemund
# Processing Record 16 of Set 5 | terrace
# Processing Record 17 of Set 5 | mattru
# Processing Record 18 of Set 5 | poya
# Processing Record 19 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 5 | pakxan
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | marawi
# Processing Record 23 of Set 5 | piracanjuba
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | carutapera
# Processing Record 26 of Set 5 | mwene-ditu
# Processing Record 27 of Set 5 | chara
# Processing Record 28 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 30 of Set 5 | chimbote
# Processing Record 31 of Set 5 | alibag
# Processing Record 32 of Set 5 | valparaiso
# Processing Record 33 of Set 5 | pustomyty
# Processing Record 34 of Set 5 | havoysund
# Processing Record 35 of Set 5 | itupiranga
# Processing Record 36 of Set 5 | itahari
# City not found. Skipping...
# Processing Record 37 of Set 5 | saint-joseph
# Processing Record 38 of Set 5 | port lincoln
# Processing Record 39 of Set 5 | castro
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | tala
# Processing Record 42 of Set 5 | tsabong
# Processing Record 43 of Set 5 | rantepao
# Processing Record 44 of Set 5 | kamenka
# Processing Record 45 of Set 5 | komsomolskiy
# Processing Record 46 of Set 5 | guatire
# Processing Record 47 of Set 5 | mareeba
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | lubao
# Processing Record 50 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 6 | east london
# Processing Record 2 of Set 6 | bagdarin
# Processing Record 3 of Set 6 | chipinge
# Processing Record 4 of Set 6 | bonthe
# Processing Record 5 of Set 6 | isangel
# Processing Record 6 of Set 6 | talaya
# Processing Record 7 of Set 6 | maraa
# Processing Record 8 of Set 6 | sobolevo
# Processing Record 9 of Set 6 | mulchen
# Processing Record 10 of Set 6 | guarapari
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | moncton
# Processing Record 13 of Set 6 | mana
# Processing Record 14 of Set 6 | prabumulih
# Processing Record 15 of Set 6 | matara
# Processing Record 16 of Set 6 | araouane
# Processing Record 17 of Set 6 | atambua
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | rorvik
# Processing Record 20 of Set 6 | upernavik
# Processing Record 21 of Set 6 | viedma
# Processing Record 22 of Set 6 | athabasca
# Processing Record 23 of Set 6 | bilibino
# Processing Record 24 of Set 6 | carnarvon
# Processing Record 25 of Set 6 | samarai
# Processing Record 26 of Set 6 | vysokogornyy
# Processing Record 27 of Set 6 | solone
# Processing Record 28 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 29 of Set 6 | tasiilaq
# Processing Record 30 of Set 6 | erenhot
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | bambous virieux
# Processing Record 33 of Set 6 | luang prabang
# Processing Record 34 of Set 6 | marzuq
# Processing Record 35 of Set 6 | bocanda
# Processing Record 36 of Set 6 | kargasok
# Processing Record 37 of Set 6 | ponta do sol
# Processing Record 38 of Set 6 | bilma
# Processing Record 39 of Set 6 | beipiao
# Processing Record 40 of Set 6 | san juan
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | hammond
# Processing Record 43 of Set 6 | teseney
# Processing Record 44 of Set 6 | namatanai
# Processing Record 45 of Set 6 | alice springs
# Processing Record 46 of Set 6 | dongsheng
# Processing Record 47 of Set 6 | grand-santi
# Processing Record 48 of Set 6 | eastbourne
# Processing Record 49 of Set 6 | hithadhoo
# Processing Record 50 of Set 6 | waddan
# Processing Record 1 of Set 7 | mafeteng
# Processing Record 2 of Set 7 | praya
# Processing Record 3 of Set 7 | chernyshevskiy
# Processing Record 4 of Set 7 | westport
# Processing Record 5 of Set 7 | viljoenskroon
# Processing Record 6 of Set 7 | kochevo
# Processing Record 7 of Set 7 | marshall
# Processing Record 8 of Set 7 | buala
# Processing Record 9 of Set 7 | tabory
# Processing Record 10 of Set 7 | oga
# Processing Record 11 of Set 7 | ulaangom
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 7 | fare
# Processing Record 15 of Set 7 | yellowknife
# Processing Record 16 of Set 7 | boyolangu
# Processing Record 17 of Set 7 | chaozhou
# Processing Record 18 of Set 7 | columbus
# Processing Record 19 of Set 7 | brae
# Processing Record 20 of Set 7 | svetlyy
# Processing Record 21 of Set 7 | jiaojiang
# Processing Record 22 of Set 7 | labuhan
# Processing Record 23 of Set 7 | acapulco
# Processing Record 24 of Set 7 | plouzane
# Processing Record 25 of Set 7 | kemijarvi
# Processing Record 26 of Set 7 | ipixuna
# Processing Record 27 of Set 7 | guerrero negro
# Processing Record 28 of Set 7 | nagua
# Processing Record 29 of Set 7 | kirakira
# Processing Record 30 of Set 7 | klaksvik
# Processing Record 31 of Set 7 | nkpor
# Processing Record 32 of Set 7 | coria
# Processing Record 33 of Set 7 | awbari
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | corinto
# Processing Record 36 of Set 7 | nuevo progreso
# Processing Record 37 of Set 7 | skibbereen
# Processing Record 38 of Set 7 | saskylakh
# Processing Record 39 of Set 7 | longyearbyen
# Processing Record 40 of Set 7 | flin flon
# Processing Record 41 of Set 7 | kavieng
# Processing Record 42 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 7 | aykhal
# Processing Record 44 of Set 7 | bukachacha
# Processing Record 45 of Set 7 | charlestown
# Processing Record 46 of Set 7 | pokrovsk
# Processing Record 47 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 48 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 7 | sao jose da coroa grande
# Processing Record 1 of Set 8 | jacareacanga
# Processing Record 2 of Set 8 | great yarmouth
# Processing Record 3 of Set 8 | kolondieba
# Processing Record 4 of Set 8 | seoul
# Processing Record 5 of Set 8 | quixada
# Processing Record 6 of Set 8 | lompoc
# Processing Record 7 of Set 8 | ape
# Processing Record 8 of Set 8 | coruripe
# Processing Record 9 of Set 8 | vanavara
# Processing Record 10 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 8 | kilimatinde
# Processing Record 12 of Set 8 | moose jaw
# Processing Record 13 of Set 8 | uyskoye
# Processing Record 14 of Set 8 | victoria
# Processing Record 15 of Set 8 | bastrop
# Processing Record 16 of Set 8 | luanda
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 8 | vao
# Processing Record 20 of Set 8 | pimentel
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | artyom
# Processing Record 23 of Set 8 | yamada
# Processing Record 24 of Set 8 | kainantu
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | novaya bryan
# Processing Record 27 of Set 8 | tura
# Processing Record 28 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 8 | kaitangata
# Processing Record 30 of Set 8 | waingapu
# Processing Record 31 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 8 | mega
# Processing Record 33 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 8 | sanger
# Processing Record 35 of Set 8 | forestville
# Processing Record 36 of Set 8 | sakakah
# Processing Record 37 of Set 8 | pitsunda
# Processing Record 38 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 8 | salta
# Processing Record 40 of Set 8 | padang
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | buin
# Processing Record 43 of Set 8 | hami
# Processing Record 44 of Set 8 | port-gentil
# Processing Record 45 of Set 8 | alappuzha
# Processing Record 46 of Set 8 | nyurba
# Processing Record 47 of Set 8 | atar
# Processing Record 48 of Set 8 | teya
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 50 of Set 8 | kavaratti
# Processing Record 1 of Set 9 | grindavik
# Processing Record 2 of Set 9 | pechenga
# Processing Record 3 of Set 9 | hastings
# Processing Record 4 of Set 9 | caravelas
# Processing Record 5 of Set 9 | ghanzi
# Processing Record 6 of Set 9 | batemans bay
# Processing Record 7 of Set 9 | maravilha
# Processing Record 8 of Set 9 | pakala
# Processing Record 9 of Set 9 | ribeira grande
# Processing Record 10 of Set 9 | saint-leu
# Processing Record 11 of Set 9 | college
# Processing Record 12 of Set 9 | lima
# Processing Record 13 of Set 9 | ishigaki
# Processing Record 14 of Set 9 | itoman
# Processing Record 15 of Set 9 | zhigansk
# Processing Record 16 of Set 9 | birao
# Processing Record 17 of Set 9 | bonnyville
# Processing Record 18 of Set 9 | japura
# Processing Record 19 of Set 9 | dunmore town
# Processing Record 20 of Set 9 | hovd
# Processing Record 21 of Set 9 | tomatlan
# Processing Record 22 of Set 9 | carnot
# Processing Record 23 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 9 | vardo
# Processing Record 25 of Set 9 | richards bay
# Processing Record 26 of Set 9 | antissa
# City not found. Skipping...
# Processing Record 27 of Set 9 | broken hill
# Processing Record 28 of Set 9 | yuryevets
# Processing Record 29 of Set 9 | la ronge
# Processing Record 30 of Set 9 | balikpapan
# Processing Record 31 of Set 9 | haines junction
# Processing Record 32 of Set 9 | whitianga
# Processing Record 33 of Set 9 | fairbanks
# Processing Record 34 of Set 9 | galle
# Processing Record 35 of Set 9 | christchurch
# Processing Record 36 of Set 9 | reitz
# Processing Record 37 of Set 9 | noumea
# Processing Record 38 of Set 9 | kapoeta
# Processing Record 39 of Set 9 | caconda
# Processing Record 40 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | clovis
# Processing Record 42 of Set 9 | bundaberg
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | tessalit
# Processing Record 45 of Set 9 | jumla
# Processing Record 46 of Set 9 | weihe
# Processing Record 47 of Set 9 | surab
# Processing Record 48 of Set 9 | manggar
# Processing Record 49 of Set 9 | vredendal
# Processing Record 50 of Set 9 | luderitz
# Processing Record 1 of Set 10 | grand-lahou
# Processing Record 2 of Set 10 | jutai
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | ocos
# Processing Record 5 of Set 10 | bentiu
# Processing Record 6 of Set 10 | salinopolis
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | fort dix
# Processing Record 9 of Set 10 | ambon
# Processing Record 10 of Set 10 | tacuarembo
# Processing Record 11 of Set 10 | masoko
# Processing Record 12 of Set 10 | lorengau
# Processing Record 13 of Set 10 | olafsvik
# Processing Record 14 of Set 10 | bailieborough
# Processing Record 15 of Set 10 | nisia floresta
# Processing Record 16 of Set 10 | santa marta
# Processing Record 17 of Set 10 | kankakee
# Processing Record 18 of Set 10 | talnakh
# Processing Record 19 of Set 10 | altay
# Processing Record 20 of Set 10 | markova
# Processing Record 21 of Set 10 | san carlos del zulia
# Processing Record 22 of Set 10 | taltal
# Processing Record 23 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 10 | altamira
# Processing Record 25 of Set 10 | hobyo
# Processing Record 26 of Set 10 | tadine
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | asfi
# Processing Record 29 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 10 | rio gallegos
# Processing Record 31 of Set 10 | tsiroanomandidy
# Processing Record 32 of Set 10 | portland
# Processing Record 33 of Set 10 | macas
# Processing Record 34 of Set 10 | kurchum
# Processing Record 35 of Set 10 | megion
# Processing Record 36 of Set 10 | tazovskiy
# Processing Record 37 of Set 10 | synya
# Processing Record 38 of Set 10 | canakkale
# Processing Record 39 of Set 10 | baherden
# Processing Record 40 of Set 10 | shelburne
# Processing Record 41 of Set 10 | bo phloi
# Processing Record 42 of Set 10 | tiksi
# Processing Record 43 of Set 10 | clarence town
# Processing Record 44 of Set 10 | iqaluit
# Processing Record 45 of Set 10 | port antonio
# Processing Record 46 of Set 10 | diffa
# Processing Record 47 of Set 10 | rockport
# Processing Record 48 of Set 10 | kinkala
# Processing Record 49 of Set 10 | jiaohe
# Processing Record 50 of Set 10 | kolar
# Processing Record 1 of Set 11 | pottsville
# Processing Record 2 of Set 11 | ushtobe
# Processing Record 3 of Set 11 | oktyabrskiy
# Processing Record 4 of Set 11 | malatya
# Processing Record 5 of Set 11 | nouadhibou
# Processing Record 6 of Set 11 | talara
# Processing Record 7 of Set 11 | morondava
# Processing Record 8 of Set 11 | port hardy
# Processing Record 9 of Set 11 | matagami
# Processing Record 10 of Set 11 | constantine
# Processing Record 11 of Set 11 | touros
# Processing Record 12 of Set 11 | ahipara
# Processing Record 13 of Set 11 | norton
# Processing Record 14 of Set 11 | gonyu
# City not found. Skipping...
# Processing Record 15 of Set 11 | karratha
# Processing Record 16 of Set 11 | auki
# Processing Record 17 of Set 11 | hay river
# Processing Record 18 of Set 11 | fougamou
# Processing Record 19 of Set 11 | tubmanburg
# Processing Record 20 of Set 11 | vlasikha
# Processing Record 21 of Set 11 | sola
# Processing Record 22 of Set 11 | kropotkin
# Processing Record 23 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 24 of Set 11 | kieta
# Processing Record 25 of Set 11 | kokstad
# Processing Record 26 of Set 11 | lydenburg
# Processing Record 27 of Set 11 | kendari
# Processing Record 28 of Set 11 | vila franca do campo
# Processing Record 29 of Set 11 | ayolas
# Processing Record 30 of Set 11 | mehamn
# Processing Record 31 of Set 11 | baykit
# Processing Record 32 of Set 11 | tibiri
# Processing Record 33 of Set 11 | smyrna
# Processing Record 34 of Set 11 | sumenep
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | murakami
# Processing Record 37 of Set 11 | santa cruz do sul
# Processing Record 38 of Set 11 | karasjok
# Processing Record 39 of Set 11 | yunyang
# Processing Record 40 of Set 11 | formosa
# Processing Record 41 of Set 11 | ingham
# Processing Record 42 of Set 11 | aakirkeby
# City not found. Skipping...
# Processing Record 43 of Set 11 | pochutla
# Processing Record 44 of Set 11 | muli
# Processing Record 45 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 11 | koshurnikovo
# Processing Record 47 of Set 11 | albanel
# Processing Record 48 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 11 | tawang
# Processing Record 50 of Set 11 | ormara
# Processing Record 1 of Set 12 | chabahar
# Processing Record 2 of Set 12 | boralday
# Processing Record 3 of Set 12 | duekoue
# Processing Record 4 of Set 12 | mangrol
# Processing Record 5 of Set 12 | madaoua
# Processing Record 6 of Set 12 | wewak
# Processing Record 7 of Set 12 | kiama
# Processing Record 8 of Set 12 | te anau
# Processing Record 9 of Set 12 | okha
# Processing Record 10 of Set 12 | kununurra
# Processing Record 11 of Set 12 | kaka
# Processing Record 12 of Set 12 | kisangani
# Processing Record 13 of Set 12 | ketchikan
# Processing Record 14 of Set 12 | oktyabrskoye
# Processing Record 15 of Set 12 | lithakia
# Processing Record 16 of Set 12 | cabo san lucas
# Processing Record 17 of Set 12 | plover
# Processing Record 18 of Set 12 | tambopata
# Processing Record 19 of Set 12 | skanderborg
# Processing Record 20 of Set 12 | boguchany
# Processing Record 21 of Set 12 | brownsville
# Processing Record 22 of Set 12 | sosnovo-ozerskoye
# Processing Record 23 of Set 12 | samana
# Processing Record 24 of Set 12 | ciudad guayana
# Processing Record 25 of Set 12 | gambela
# Processing Record 26 of Set 12 | cutlerville
# Processing Record 27 of Set 12 | rabo de peixe
# Processing Record 28 of Set 12 | bud
# Processing Record 29 of Set 12 | maningrida
# Processing Record 30 of Set 12 | novoseleznevo
# Processing Record 31 of Set 12 | vesyegonsk
# Processing Record 32 of Set 12 | uni
# Processing Record 33 of Set 12 | kenai
# Processing Record 34 of Set 12 | wangou
# Processing Record 35 of Set 12 | karaton
# Processing Record 36 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 37 of Set 12 | gorontalo
# Processing Record 38 of Set 12 | san andres
# Processing Record 39 of Set 12 | filadelfia
# Processing Record 40 of Set 12 | mount isa
# Processing Record 41 of Set 12 | ylivieska
# Processing Record 42 of Set 12 | dolores
# Processing Record 43 of Set 12 | anastasiyevskaya
# Processing Record 44 of Set 12 | thunder bay
# Processing Record 45 of Set 12 | lagoa
# Processing Record 46 of Set 12 | dudinka
# Processing Record 47 of Set 12 | broome
# Processing Record 48 of Set 12 | basoko
# Processing Record 49 of Set 12 | qianguo
# Processing Record 50 of Set 12 | of
# City not found. Skipping...
# Processing Record 1 of Set 13 | churapcha
# Processing Record 2 of Set 13 | kotido
# Processing Record 3 of Set 13 | tipitapa
# Processing Record 4 of Set 13 | burica
# City not found. Skipping...
# Processing Record 5 of Set 13 | tilichiki
# Processing Record 6 of Set 13 | simao
# Processing Record 7 of Set 13 | lastoursville
# Processing Record 8 of Set 13 | pascagoula
# Processing Record 9 of Set 13 | bereda
# Processing Record 10 of Set 13 | salalah
# Processing Record 11 of Set 13 | gizo
# Processing Record 12 of Set 13 | nelson bay
# Processing Record 13 of Set 13 | zaozerne
# Processing Record 14 of Set 13 | homer
# Processing Record 15 of Set 13 | pangnirtung
# Processing Record 16 of Set 13 | mandalay
# Processing Record 17 of Set 13 | salinas
# Processing Record 18 of Set 13 | mackay
# Processing Record 19 of Set 13 | saint-junien
# Processing Record 20 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 21 of Set 13 | creston
# Processing Record 22 of Set 13 | bata
# Processing Record 23 of Set 13 | beinamar
# Processing Record 24 of Set 13 | andenes
# Processing Record 25 of Set 13 | belmonte
# Processing Record 26 of Set 13 | durban
# Processing Record 27 of Set 13 | siuna
# Processing Record 28 of Set 13 | ibra
# Processing Record 29 of Set 13 | slave lake
# Processing Record 30 of Set 13 | lufkin
# Processing Record 31 of Set 13 | antalaha
# Processing Record 32 of Set 13 | narsaq
# Processing Record 33 of Set 13 | mogadishu
# Processing Record 34 of Set 13 | punta cardon
# Processing Record 35 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 13 | vostok
# Processing Record 37 of Set 13 | omsukchan
# Processing Record 38 of Set 13 | chicama
# Processing Record 39 of Set 13 | horsham
# Processing Record 40 of Set 13 | pontiac
# Processing Record 41 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 13 | benguela
# Processing Record 43 of Set 13 | cervo
# Processing Record 44 of Set 13 | gornopravdinsk
# Processing Record 45 of Set 13 | dingle
# Processing Record 46 of Set 13 | fuyu
# Processing Record 47 of Set 13 | alofi
# Processing Record 48 of Set 13 | alimanguan
# City not found. Skipping...
# Processing Record 49 of Set 13 | saqqez
# Processing Record 50 of Set 13 | bagrami
# Processing Record 1 of Set 14 | amga
# Processing Record 2 of Set 14 | laguna
# Processing Record 3 of Set 14 | moroni
# Processing Record 4 of Set 14 | talcahuano
# Processing Record 5 of Set 14 | bontang
# Processing Record 6 of Set 14 | torbay
# Processing Record 7 of Set 14 | aberdeen
# Processing Record 8 of Set 14 | labuan
# Processing Record 9 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 10 of Set 14 | namibe
# Processing Record 11 of Set 14 | harwich
# Processing Record 12 of Set 14 | brownwood
# Processing Record 13 of Set 14 | kismayo
# Processing Record 14 of Set 14 | teahupoo
# Processing Record 15 of Set 14 | pyay
# Processing Record 16 of Set 14 | mbandaka
# Processing Record 17 of Set 14 | al
# City not found. Skipping...
# Processing Record 18 of Set 14 | manzanillo
# Processing Record 19 of Set 14 | susaki
# Processing Record 20 of Set 14 | basco
# Processing Record 21 of Set 14 | ovalle
# Processing Record 22 of Set 14 | henties bay
# Processing Record 23 of Set 14 | turukhansk
# Processing Record 24 of Set 14 | san carlos
# Processing Record 25 of Set 14 | comodoro rivadavia
# Processing Record 26 of Set 14 | puerto suarez
# Processing Record 27 of Set 14 | jalu
# Processing Record 28 of Set 14 | fomboni
# Processing Record 29 of Set 14 | mhlume
# Processing Record 30 of Set 14 | bani walid
# Processing Record 31 of Set 14 | kotka
# Processing Record 32 of Set 14 | saint george
# Processing Record 33 of Set 14 | nuevo ideal
# Processing Record 34 of Set 14 | port augusta
# Processing Record 35 of Set 14 | ilam
# Processing Record 36 of Set 14 | wainwright
# Processing Record 37 of Set 14 | nogales
# Processing Record 38 of Set 14 | vicuna
# Processing Record 39 of Set 14 | rafai
# Processing Record 40 of Set 14 | garissa
# Processing Record 41 of Set 14 | korla
# Processing Record 42 of Set 14 | bolobo
# Processing Record 43 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 14 | panama city
# Processing Record 45 of Set 14 | puerto del rosario
# Processing Record 46 of Set 14 | antofagasta
# Processing Record 47 of Set 14 | kresttsy
# Processing Record 48 of Set 14 | emerald
# Processing Record 49 of Set 14 | zemio
# Processing Record 50 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 15 | dunyapur
# Processing Record 3 of Set 15 | jiexiu
# Processing Record 4 of Set 15 | san rafael
# Processing Record 5 of Set 15 | puerto leguizamo
# Processing Record 6 of Set 15 | balkhash
# Processing Record 7 of Set 15 | ouesso
# Processing Record 8 of Set 15 | angra
# City not found. Skipping...
# Processing Record 9 of Set 15 | pahrump
# Processing Record 10 of Set 15 | concepcion del uruguay
# Processing Record 11 of Set 15 | ikom
# Processing Record 12 of Set 15 | tshikapa
# Processing Record 13 of Set 15 | campo largo
# Processing Record 14 of Set 15 | beidao
# Processing Record 15 of Set 15 | nizhnevartovsk
# Processing Record 16 of Set 15 | ugoofaaru
# Processing Record 17 of Set 15 | biak
# Processing Record 18 of Set 15 | vallenar
# Processing Record 19 of Set 15 | mundra
# Processing Record 20 of Set 15 | port keats
# Processing Record 21 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 15 | mehran
# Processing Record 23 of Set 15 | abalak
# Processing Record 24 of Set 15 | sandnessjoen
# Processing Record 25 of Set 15 | wajima
# Processing Record 26 of Set 15 | leh
# Processing Record 27 of Set 15 | roma
# Processing Record 28 of Set 15 | havre-saint-pierre
# Processing Record 29 of Set 15 | sagua la grande
# Processing Record 30 of Set 15 | northam
# Processing Record 31 of Set 15 | marsa matruh
# Processing Record 32 of Set 15 | massaguet
# Processing Record 33 of Set 15 | harlingen
# Processing Record 34 of Set 15 | luganville
# Processing Record 35 of Set 15 | gweta
# Processing Record 36 of Set 15 | marabba
# Processing Record 37 of Set 15 | road town
# Processing Record 38 of Set 15 | khandyga
# Processing Record 39 of Set 15 | elliot
# Processing Record 40 of Set 15 | chateaubelair
# Processing Record 41 of Set 15 | mari-turek
# Processing Record 42 of Set 15 | yako
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0       Hilo      US  2021-02-15 02:56:52  19.7297 -155.0900     80.60
# 1  Raudeberg      NO  2021-02-15 02:56:52  61.9875    5.1352     41.00
# 2    Ushuaia      AR  2021-02-15 02:56:52 -54.8000  -68.3000     48.20
# 3    Mataura      NZ  2021-02-15 02:56:52 -46.1927  168.8643     59.00
# 4  Maniitsoq      GL  2021-02-15 02:56:53  65.4167  -52.9000      4.08
# 5       Lebu      CL  2021-02-15 02:56:53 -37.6167  -73.6500     57.60
# 6   Valdivia      CL  2021-02-15 02:56:53 -39.8142  -73.2459     55.40
# 7     Harper      LR  2021-02-15 02:56:53   4.3750   -7.7169     78.19
# 8       Asau      RO  2021-02-15 02:56:53  46.4333   26.4000     26.60
# 9      Sitka      US  2021-02-15 02:56:53  57.0531 -135.3300     33.80
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        69          20       14.97          few clouds
# 1        57         100       24.00          light rain
# 2        66          75        5.88       broken clouds
# 3        70          96       14.00     overcast clouds
# 4        88          77       12.33       broken clouds
# 5        80           0       19.06           clear sky
# 6        71           0        3.44           clear sky
# 7        89          79        5.88       broken clouds
# 8        80          90        4.61     overcast clouds
# 9        51          90       10.36     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
